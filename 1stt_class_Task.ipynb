# %%
number = 5 
for i in range(1, 12, 1):
    print(number, "X", i, "=", number*i )
# Out:
# 5 X 1 = 5
# 5 X 2 = 10
# 5 X 3 = 15
# 5 X 4 = 20
# 5 X 5 = 25
# 5 X 6 = 30
# 5 X 7 = 35
# 5 X 8 = 40
# 5 X 9 = 45
# 5 X 10 = 50
# 5 X 11 = 55

# %%
dic = {
    "Name" : "Sajad ullah", 
    "F.name" : "Kamal khan", 
    "Roll.no" : 557570, 
    "semester" : "3rd Semester", 
    "Dept" : "Computer science", 
    "GPA" : 3.68
}
print(dic["Name"])
print(dic["GPA"])
print(dic["Roll.no"])
# Out:
# Sajad ullah
# 3.68
# 557570

# %%
str = "Sajad ullah" 
print(str[2])

# %%
name = "Sajad ullah"
if name == "Sajad ullah":
    print("Login seccessfully..")
else:
    print("Please try again...")
# Out:
# Login seccessfully..

# %%
name = "Sajad ullah" 
f_name = "Kamal khan" 
print("My naem is", name, "and my father name is", f_name)
# Out:
# My naem is Sajad ullah and my father name is Kamal khan

# %%
age = 19 
if age >= 18:
    print("your adult")
else:
    print("boy")
# Out:
# your adult

# %%
print("I love codding..")
# Out:
# I love cpdding..

# %%
email = "sajadullah241@gmail.com"
password = "Sajad.123"
if email == "sajadullah241@gmail.com" and password == "Sajad.123":
    print("Login seccessfully..")
else:
    print("email or pass is incorrect. please try again..")
# Out:
# Login seccessfully..

# %%
number = 5 
if number % 2 == 0 :
    print("you have entered Even number")
else:
    print("You have entered Odd number")
# Out:
# You have entered Odd number

# %%
number = 6 
print("You have enterd ", number)
# Out:
# You have enterd  6

# %%
name = "Sajad ullah" 
print("Yours name is:", name)
# Out:
# Yours name is: Sajad ullah

# %%
print("I am learing python.\n After learning python than I will lern Django.")
# Out:
# I am learing python.
#  After learning python than I will lern Django.

# %%
D_E = "Data Engieneer"
print("I want to be a", D_E, ".")
# Out:
# I want to be a Data Engieneer .

# %%
num = 7 
print("Remainder of", num, "is", num/2)
# Out:
# Remainder of 7 is 3.5

# %%
computer = "Computer Science"
D_Engeineer = "Data Engieneer"
print("I am a", computer, "Student and I want to be a", D_Engeineer, "at software house." )
# Out:
# I am a Computer Science Student and I want to be a Data Engieneer at software house.

# %%
print("I love Technology..")
# Out:
# I love Technology..

# %%
for i in range(1, 10, 1): # (Start, Stop, Steps)
    print("Hello world")
# Out:
# Hello world
# Hello world
# Hello world
# Hello world
# Hello world
# Hello world
# Hello world
# Hello world
# Hello world

# %%
print("University Of Lorali")
# Out:
# University Of Lorali

# %%
print("Is Data Engeineering is a good field?")
# Out:
# Is Data Engeineering is a good field?

# %%
name = "Sajad ullah" 
name = str(input("Enter your name:"))
if name == "Sajad ullah":
    print("Login secsessfully .")
else:
    print("username is incorrect please try agian...")

# %%
print("Hi, I am a BS Computer Science Students at UOLi.")

# %%
answer = "Buietms University is the great ranking university for all easa University of Loralai is nothing and its not compair with Buitems ==>> hahahah."
print("University Of Lorlai VS Buitems:", answer)
# Out:
# University Of Lorlai VS Buitems: Buietms University is the great ranking university for all easa University of Loralai is nothing and its not compair with Buitems ==>> hahahah.

# %%
print("Computer is the best careire of the world..")
# Out:
# Computer is the best careire of the world..

# %%
print("Codding is my dreem you know..")
# Out:
# Codding is my dreem you know..

# %%
marks = 90
if marks >= 50 :
    print("Pass")
else:
    print("Fail")

# %%
print("Data engieneering is one of the demanded filed for a software house beacause any organizition has alot of data. you know haha")
# Out:
# Data engieneering is one of the demanded filed for a software house beacause any organizition has alot of data. you know haha

# %%
print("Hello world")
# Out:
# Hello world

# %%
print("Python is the easy language for begners..")
# Out:
# Python is the easy language for begners..

# %%
fan = "I am fan."
print("How are you? \n", fan)
# Out:
# How are you?
#  I am fan.

# %%
name = "Sajad ullah " 
print("My name is : ", name)
# Out:
# My name is :  Sajad ullah

# %%
print("Subtrection of the values:", 9 - 8)
# Out:
# Subtrection of the values: 1

# %%
print("Multiplication of the values:", 9 * 5)
# Out:
# Multiplication of the values: 45

# %%
print("Sum of the values:", 3 + 97 )
# Out:
# Sum of the values: 100

# %%
print("I am a pakistani, and you")
# Out:
# I am a pakistani, and you

# %%
print("I want to be a Data Engieneer at a software house.")
# Out:
# I want to be a Data Engieneer at a software house.

# %%
print("Hi, I am Sajad ullah")
# Out:
# Hi, I am Sajad ullah

# %%
print("I am learning python for Data science")
# Out:
# I am learning python for Data science
